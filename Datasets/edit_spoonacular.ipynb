# %%
#Import Dependencies
import pandas as pd
import requests
import json

# %%
#Spoonacular API Recipe List JSON 1 (All Purpose Flour):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"all purpose flour","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_1.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 2 (Almond):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"almond","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_2.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 3 (Apple Cider Vinegar):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"apple cider vinegar","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_3.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 4 (Bacon):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"bacon","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_4.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 5 (Baker's Yeast):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"yeast","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_5.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 6 (Baking Powder):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"baking powder","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_6.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 7 (Baking Soda):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"baking soda","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_7.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 8 (fish):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"fish","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_8.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 9 (Banana):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"banana","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_9.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 10 (Basil):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"basil","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_10.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 11 (Beef):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"beef","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_11.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 12 (Black Pepper):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"black pepper","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_12.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 13 (Blueberry):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"blueberry","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_13.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 14 (Brown Sugar):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"brown sugar","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_14.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 15 (Butter):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"butter","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_15.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 16 (Cabbage):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cabbage","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_16.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 17 (Cane Sugar):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cane sugar","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_17.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 18 (Canola Oil):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"canola oil","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_18.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 19 (Carrot):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"carrot","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_19.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 20 (Celery):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"celery","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_20.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 21 (Turkey):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"turkey","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_21.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 22 (Cheese):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cheese","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_22.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 23 (Chicken):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"chicken","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_23.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 24 (Chicken Broth):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"chicken broth","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_24.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 25 (Chuck Roast):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"chuck roast","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_25.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 26 (Cilantro):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cilantro","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_26.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 27 (Clove):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"clove","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_27.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 28 (Cocoa Powder):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cocoa powder","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_28.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 29 (Coconut):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"coconut","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_29.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 30 (Coconut Milk):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"coconut milk","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_30.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 31 (Corn Syrup):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"corn syrup","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_31.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 32 (Corned Beef):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"corned beef","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_32.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 33 (Cornstarch):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cornstarch","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_33.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 34 (Cow Milk):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cow milk","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_34.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 35 (Dried Cranberry):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"dried cranberry","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_35.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 36 (Egg):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"egg","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_36.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 37 (Garlic):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"garlic","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_37.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 38 (Gluten Free Flour):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"gluten free flour","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_38.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 39 (Green Onion):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"green onion","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_39.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 40 (Green Pepper):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"green pepper","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_40.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 41 (Honey):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"honey","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_41.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 42 (Lamb):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"lamb","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_42.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 43 (Lemon Juice):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"lemon juice","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_43.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 44 (Mayonnaise):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"mayonnaise","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_44.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 45 (Oat):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"oat","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_45.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 46 (Olive Oil):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"olive oil","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_46.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 47 (Onion):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"onion","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_47.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 48 (Oregano):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"oregano","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_48.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 49 (Paprika):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"paprika","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_49.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 50 (Parsley):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"parsley","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_50.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 51 (Peanut):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"peanut","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_51.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 52 (Pecan):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"pecan","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_52.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 53 (Potato):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"potato","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_53.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 54 (Pumpkin Seed):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"pumpkin seed","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_54.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 55 (Crab):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"crab","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_55.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 56 (Salt):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"salt","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_56.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 57 (Sesame Oil):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"sesame oil","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_57.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 58 (Soy Sauce):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"soy sauce","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_58.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 59 (Tapioca Flour):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"tapioca flour","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_59.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 60 (Tarragon):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"tarragon","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_60.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 61 (Seaweed):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"seaweed","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_61.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 62 (Tomato):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"tomato","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_62.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 63 (Vanilla Extract):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"vanilla extract","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_63.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 64 (Vegetable Oil):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"vegetable oil","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_64.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 65 (Walnut):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"walnut","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_65.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 66 (Water):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"water","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_66.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 67 (Bread):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"bread","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_67.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 68 (Shrimp):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"shrimp","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_68.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 69 (White Vinegar):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"white vinegar","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_69.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 70 (Mustard):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"mustard","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_70.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 71 (Whole Wheat Flour):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"whole wheat flour","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_71.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 72 (Chocolate):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"chocolate","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_72.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 73 (Duck):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"duck","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_73.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 74 (Strawberry):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"strawberry","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_74.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 75 (Mushroom):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"mushroom","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_75.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 76 (Anchovy):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"anchovy","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_76.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 77 (Crawfish):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"crawfish","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_77.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 78 (Apple):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"apple","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_78.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Spoonacular API Recipe List JSON 79 (Cheese):
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/random"

querystring = {"tags":"cheese","number":"100"}

headers = {
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com",
    'x-rapidapi-key': "3909245fe8msh2162ec791f4d00ap1e234ejsnf21796e5d332"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
with open('spoonacular_recipe_list_79.json', 'wb') as outf:
    outf.write(response.content)

# %%
#Output Neo4j Column Types in Recipe List 1 (All Purpose Flour):
data_rl1=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_1.csv')
df_rl1=pd.DataFrame(data_rl1)
df_rl1.columns = df_rl1.columns.str.replace('recipes/', '')
df_rl1.columns = df_rl1.columns.str.replace('/', '_')
rl1_list=[]
for columnName in df_rl1.columns:
    if df_rl1.dtypes[columnName] == 'bool':
        rl1_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl1.dtypes[columnName] == 'object':
        rl1_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl1.dtypes[columnName] == 'int64':
        rl1_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl1.dtypes[columnName] == 'float64':
        rl1_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl1.to_csv('D:\DSE Files\data\spoonacular_recipe_list_1.csv')
with open("rl1_list.txt", 'w') as output:
    for row in rl1_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 2 (Almond):
data_rl2=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_2.csv')
df_rl2=pd.DataFrame(data_rl2)
df_rl2.columns = df_rl2.columns.str.replace('recipes/', '')
df_rl2.columns = df_rl2.columns.str.replace('/', '_')
rl2_list=[]
for columnName in df_rl2.columns:
    if df_rl2.dtypes[columnName] == 'bool':
        rl2_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl2.dtypes[columnName] == 'object':
        rl2_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl2.dtypes[columnName] == 'int64':
        rl2_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl2.dtypes[columnName] == 'float64':
        rl2_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl2.to_csv('D:\DSE Files\data\spoonacular_recipe_list_2.csv')
with open("rl2_list.txt", 'w') as output:
    for row in rl2_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 3 (Apple Cider Vinegar):
data_rl3=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_3.csv')
df_rl3=pd.DataFrame(data_rl3)
df_rl3.columns = df_rl3.columns.str.replace('recipes/', '')
df_rl3.columns = df_rl3.columns.str.replace('/', '_')
rl3_list=[]
for columnName in df_rl3.columns:
    if df_rl3.dtypes[columnName] == 'bool':
        rl3_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl3.dtypes[columnName] == 'object':
        rl3_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl3.dtypes[columnName] == 'int64':
        rl3_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl3.dtypes[columnName] == 'float64':
        rl3_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl3.to_csv('D:\DSE Files\data\spoonacular_recipe_list_3.csv')
with open("rl3_list.txt", 'w') as output:
    for row in rl3_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 4 (Bacon):
data_rl4=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_4.csv')
df_rl4=pd.DataFrame(data_rl4)
df_rl4.columns = df_rl4.columns.str.replace('recipes/', '')
df_rl4.columns = df_rl4.columns.str.replace('/', '_')
rl4_list=[]
for columnName in df_rl4.columns:
    if df_rl4.dtypes[columnName] == 'bool':
        rl4_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl4.dtypes[columnName] == 'object':
        rl4_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl4.dtypes[columnName] == 'int64':
        rl4_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl4.dtypes[columnName] == 'float64':
        rl4_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl4.to_csv('D:\DSE Files\data\spoonacular_recipe_list_4.csv')
with open("rl4_list.txt", 'w') as output:
    for row in rl4_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 5 (Baker's Yeast):
data_rl5=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_5.csv')
df_rl5=pd.DataFrame(data_rl5)
df_rl5.columns = df_rl5.columns.str.replace('recipes/', '')
df_rl5.columns = df_rl5.columns.str.replace('/', '_')
rl5_list=[]
for columnName in df_rl5.columns:
    if df_rl5.dtypes[columnName] == 'bool':
        rl5_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl5.dtypes[columnName] == 'object':
        rl5_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl5.dtypes[columnName] == 'int64':
        rl5_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl5.dtypes[columnName] == 'float64':
        rl5_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl5.to_csv('D:\DSE Files\data\spoonacular_recipe_list_5.csv')
with open("rl5_list.txt", 'w') as output:
    for row in rl5_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 6 (Baking Powder):
data_rl6=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_6.csv')
df_rl6=pd.DataFrame(data_rl6)
df_rl6.columns = df_rl6.columns.str.replace('recipes/', '')
df_rl6.columns = df_rl6.columns.str.replace('/', '_')
rl6_list=[]
for columnName in df_rl6.columns:
    if df_rl6.dtypes[columnName] == 'bool':
        rl6_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl6.dtypes[columnName] == 'object':
        rl6_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl6.dtypes[columnName] == 'int64':
        rl6_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl6.dtypes[columnName] == 'float64':
        rl6_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl6.to_csv('D:\DSE Files\data\spoonacular_recipe_list_6.csv')
with open("rl6_list.txt", 'w') as output:
    for row in rl6_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 7 (Baking Soda):
data_rl7=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_7.csv')
df_rl7=pd.DataFrame(data_rl7)
df_rl7.columns = df_rl7.columns.str.replace('recipes/', '')
df_rl7.columns = df_rl7.columns.str.replace('/', '_')
rl7_list=[]
for columnName in df_rl7.columns:
    if df_rl7.dtypes[columnName] == 'bool':
        rl7_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl7.dtypes[columnName] == 'object':
        rl7_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl7.dtypes[columnName] == 'int64':
        rl7_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl7.dtypes[columnName] == 'float64':
        rl7_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl7.to_csv('D:\DSE Files\data\spoonacular_recipe_list_7.csv')
with open("rl7_list.txt", 'w') as output:
    for row in rl7_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 8 (Fish):
data_rl8=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_8.csv')
df_rl8=pd.DataFrame(data_rl8)
df_rl8.columns = df_rl8.columns.str.replace('recipes/', '')
df_rl8.columns = df_rl8.columns.str.replace('/', '_')
rl8_list=[]
for columnName in df_rl8.columns:
    if df_rl8.dtypes[columnName] == 'bool':
        rl8_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl8.dtypes[columnName] == 'object':
        rl8_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl8.dtypes[columnName] == 'int64':
        rl8_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl8.dtypes[columnName] == 'float64':
        rl8_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl8.to_csv('D:\DSE Files\data\spoonacular_recipe_list_8.csv')
with open("rl8_list.txt", 'w') as output:
    for row in rl8_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 9 (Banana):
data_rl9=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_9.csv')
df_rl9=pd.DataFrame(data_rl9)
df_rl9.columns = df_rl9.columns.str.replace('recipes/', '')
df_rl9.columns = df_rl9.columns.str.replace('/', '_')
rl9_list=[]
for columnName in df_rl9.columns:
    if df_rl9.dtypes[columnName] == 'bool':
        rl9_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl9.dtypes[columnName] == 'object':
        rl9_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl9.dtypes[columnName] == 'int64':
        rl9_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl9.dtypes[columnName] == 'float64':
        rl9_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl9.to_csv('D:\DSE Files\data\spoonacular_recipe_list_9.csv')
with open("rl9_list.txt", 'w') as output:
    for row in rl9_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 10 (Basil):
data_rl10=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_10.csv')
df_rl10=pd.DataFrame(data_rl10)
df_rl10.columns = df_rl10.columns.str.replace('recipes/', '')
df_rl10.columns = df_rl10.columns.str.replace('/', '_')
rl10_list=[]
for columnName in df_rl10.columns:
    if df_rl10.dtypes[columnName] == 'bool':
        rl10_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl10.dtypes[columnName] == 'object':
        rl10_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl10.dtypes[columnName] == 'int64':
        rl10_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl10.dtypes[columnName] == 'float64':
        rl10_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl10.to_csv('D:\DSE Files\data\spoonacular_recipe_list_10.csv')
with open("rl10_list.txt", 'w') as output:
    for row in rl10_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 11 (Beef):
data_rl11=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_11.csv')
df_rl11=pd.DataFrame(data_rl11)
df_rl11.columns = df_rl11.columns.str.replace('recipes/', '')
df_rl11.columns = df_rl11.columns.str.replace('/', '_')
rl11_list=[]
for columnName in df_rl11.columns:
    if df_rl11.dtypes[columnName] == 'bool':
        rl11_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl11.dtypes[columnName] == 'object':
        rl11_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl11.dtypes[columnName] == 'int64':
        rl11_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl11.dtypes[columnName] == 'float64':
        rl11_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl11.to_csv('D:\DSE Files\data\spoonacular_recipe_list_11.csv')
with open("rl11_list.txt", 'w') as output:
    for row in rl11_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 12 (Black Pepper):
data_rl12=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_12.csv')
df_rl12=pd.DataFrame(data_rl12)
df_rl12.columns = df_rl12.columns.str.replace('recipes/', '')
df_rl12.columns = df_rl12.columns.str.replace('/', '_')
rl12_list=[]
for columnName in df_rl12.columns:
    if df_rl12.dtypes[columnName] == 'bool':
        rl12_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl12.dtypes[columnName] == 'object':
        rl12_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl12.dtypes[columnName] == 'int64':
        rl12_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl12.dtypes[columnName] == 'float64':
        rl12_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl12.to_csv('D:\DSE Files\data\spoonacular_recipe_list_12.csv')
with open("rl12_list.txt", 'w') as output:
    for row in rl12_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 13 (Blueberry):
data_rl13=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_13.csv')
df_rl13=pd.DataFrame(data_rl13)
df_rl13.columns = df_rl13.columns.str.replace('recipes/', '')
df_rl13.columns = df_rl13.columns.str.replace('/', '_')
rl13_list=[]
for columnName in df_rl13.columns:
    if df_rl13.dtypes[columnName] == 'bool':
        rl13_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl13.dtypes[columnName] == 'object':
        rl13_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl13.dtypes[columnName] == 'int64':
        rl13_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl13.dtypes[columnName] == 'float64':
        rl13_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl13.to_csv('D:\DSE Files\data\spoonacular_recipe_list_13.csv')
with open("rl13_list.txt", 'w') as output:
    for row in rl13_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 14 (Brown Sugar):
data_rl14=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_14.csv')
df_rl14=pd.DataFrame(data_rl14)
df_rl14.columns = df_rl14.columns.str.replace('recipes/', '')
df_rl14.columns = df_rl14.columns.str.replace('/', '_')
rl14_list=[]
for columnName in df_rl14.columns:
    if df_rl14.dtypes[columnName] == 'bool':
        rl14_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl14.dtypes[columnName] == 'object':
        rl14_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl14.dtypes[columnName] == 'int64':
        rl14_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl14.dtypes[columnName] == 'float64':
        rl14_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl14.to_csv('D:\DSE Files\data\spoonacular_recipe_list_14.csv')
with open("rl14_list.txt", 'w') as output:
    for row in rl14_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 15 (Butter):
data_rl15=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_15.csv')
df_rl15=pd.DataFrame(data_rl15)
df_rl15.columns = df_rl15.columns.str.replace('recipes/', '')
df_rl15.columns = df_rl15.columns.str.replace('/', '_')
rl15_list=[]
for columnName in df_rl15.columns:
    if df_rl15.dtypes[columnName] == 'bool':
        rl15_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl15.dtypes[columnName] == 'object':
        rl15_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl15.dtypes[columnName] == 'int64':
        rl15_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl15.dtypes[columnName] == 'float64':
        rl15_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl15.to_csv('D:\DSE Files\data\spoonacular_recipe_list_15.csv')
with open("rl15_list.txt", 'w') as output:
    for row in rl15_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 16 (Cabbage):
data_rl16=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_16.csv')
df_rl16=pd.DataFrame(data_rl16)
df_rl16.columns = df_rl16.columns.str.replace('recipes/', '')
df_rl16.columns = df_rl16.columns.str.replace('/', '_')
rl16_list=[]
for columnName in df_rl16.columns:
    if df_rl16.dtypes[columnName] == 'bool':
        rl16_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl16.dtypes[columnName] == 'object':
        rl16_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl16.dtypes[columnName] == 'int64':
        rl16_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl16.dtypes[columnName] == 'float64':
        rl16_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl16.to_csv('D:\DSE Files\data\spoonacular_recipe_list_16.csv')
with open("rl16_list.txt", 'w') as output:
    for row in rl16_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 17 (Cane Sugar):
data_rl17=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_17.csv')
df_rl17=pd.DataFrame(data_rl17)
df_rl17.columns = df_rl17.columns.str.replace('recipes/', '')
df_rl17.columns = df_rl17.columns.str.replace('/', '_')
rl17_list=[]
for columnName in df_rl17.columns:
    if df_rl17.dtypes[columnName] == 'bool':
        rl17_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl17.dtypes[columnName] == 'object':
        rl17_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl17.dtypes[columnName] == 'int64':
        rl17_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl17.dtypes[columnName] == 'float64':
        rl17_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl17.to_csv('D:\DSE Files\data\spoonacular_recipe_list_17.csv')
with open("rl17_list.txt", 'w') as output:
    for row in rl17_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 18 (Canola Oil):
data_rl18=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_18.csv')
df_rl18=pd.DataFrame(data_rl18)
df_rl18.columns = df_rl18.columns.str.replace('recipes/', '')
df_rl18.columns = df_rl18.columns.str.replace('/', '_')
rl18_list=[]
for columnName in df_rl18.columns:
    if df_rl18.dtypes[columnName] == 'bool':
        rl18_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl18.dtypes[columnName] == 'object':
        rl18_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl18.dtypes[columnName] == 'int64':
        rl18_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl18.dtypes[columnName] == 'float64':
        rl18_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl18.to_csv('D:\DSE Files\data\spoonacular_recipe_list_18.csv')
with open("rl18_list.txt", 'w') as output:
    for row in rl18_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 19 (Carrot):
data_rl19=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_19.csv')
df_rl19=pd.DataFrame(data_rl19)
df_rl19.columns = df_rl19.columns.str.replace('recipes/', '')
df_rl19.columns = df_rl19.columns.str.replace('/', '_')
rl19_list=[]
for columnName in df_rl19.columns:
    if df_rl19.dtypes[columnName] == 'bool':
        rl19_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl19.dtypes[columnName] == 'object':
        rl19_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl19.dtypes[columnName] == 'int64':
        rl19_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl19.dtypes[columnName] == 'float64':
        rl19_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl19.to_csv('D:\DSE Files\data\spoonacular_recipe_list_19.csv')
with open("rl19_list.txt", 'w') as output:
    for row in rl19_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 20 (Celery):
data_rl20=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_20.csv')
df_rl20=pd.DataFrame(data_rl20)
df_rl20.columns = df_rl20.columns.str.replace('recipes/', '')
df_rl20.columns = df_rl20.columns.str.replace('/', '_')
rl20_list=[]
for columnName in df_rl20.columns:
    if df_rl20.dtypes[columnName] == 'bool':
        rl20_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl20.dtypes[columnName] == 'object':
        rl20_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl20.dtypes[columnName] == 'int64':
        rl20_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl20.dtypes[columnName] == 'float64':
        rl20_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl20.to_csv('D:\DSE Files\data\spoonacular_recipe_list_20.csv')
with open("rl20_list.txt", 'w') as output:
    for row in rl20_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 21 (Turkey):
data_rl21=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_21.csv')
df_rl21=pd.DataFrame(data_rl21)
df_rl21.columns = df_rl21.columns.str.replace('recipes/', '')
df_rl21.columns = df_rl21.columns.str.replace('/', '_')
rl21_list=[]
for columnName in df_rl21.columns:
    if df_rl21.dtypes[columnName] == 'bool':
        rl21_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl21.dtypes[columnName] == 'object':
        rl21_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl21.dtypes[columnName] == 'int64':
        rl21_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl21.dtypes[columnName] == 'float64':
        rl21_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl21.to_csv('D:\DSE Files\data\spoonacular_recipe_list_21.csv')
with open("rl21_list.txt", 'w') as output:
    for row in rl21_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 22 (Cheese):
data_rl22=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_22.csv')
df_rl22=pd.DataFrame(data_rl22)
df_rl22.columns = df_rl22.columns.str.replace('recipes/', '')
df_rl22.columns = df_rl22.columns.str.replace('/', '_')
rl22_list=[]
for columnName in df_rl22.columns:
    if df_rl22.dtypes[columnName] == 'bool':
        rl22_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl22.dtypes[columnName] == 'object':
        rl22_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl22.dtypes[columnName] == 'int64':
        rl22_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl22.dtypes[columnName] == 'float64':
        rl22_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl22.to_csv('D:\DSE Files\data\spoonacular_recipe_list_22.csv')
with open("rl22_list.txt", 'w') as output:
    for row in rl22_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 23 (Chicken):
data_rl23=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_23.csv')
df_rl23=pd.DataFrame(data_rl23)
df_rl23.columns = df_rl23.columns.str.replace('recipes/', '')
df_rl23.columns = df_rl23.columns.str.replace('/', '_')
rl23_list=[]
for columnName in df_rl23.columns:
    if df_rl23.dtypes[columnName] == 'bool':
        rl23_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl23.dtypes[columnName] == 'object':
        rl23_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl23.dtypes[columnName] == 'int64':
        rl23_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl23.dtypes[columnName] == 'float64':
        rl23_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl23.to_csv('D:\DSE Files\data\spoonacular_recipe_list_23.csv')
with open("rl23_list.txt", 'w') as output:
    for row in rl23_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 24 (Chicken Broth):
data_rl24=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_24.csv')
df_rl24=pd.DataFrame(data_rl24)
df_rl24.columns = df_rl24.columns.str.replace('recipes/', '')
df_rl24.columns = df_rl24.columns.str.replace('/', '_')
rl24_list=[]
for columnName in df_rl24.columns:
    if df_rl24.dtypes[columnName] == 'bool':
        rl24_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl24.dtypes[columnName] == 'object':
        rl24_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl24.dtypes[columnName] == 'int64':
        rl24_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl24.dtypes[columnName] == 'float64':
        rl24_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl24.to_csv('D:\DSE Files\data\spoonacular_recipe_list_24.csv')
with open("rl24_list.txt", 'w') as output:
    for row in rl24_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 25 (Chuck Roast):
data_rl25=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_25.csv')
df_rl25=pd.DataFrame(data_rl25)
df_rl25.columns = df_rl25.columns.str.replace('recipes/', '')
df_rl25.columns = df_rl25.columns.str.replace('/', '_')
rl25_list=[]
for columnName in df_rl25.columns:
    if df_rl25.dtypes[columnName] == 'bool':
        rl25_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl25.dtypes[columnName] == 'object':
        rl25_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl25.dtypes[columnName] == 'int64':
        rl25_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl25.dtypes[columnName] == 'float64':
        rl25_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl25.to_csv('D:\DSE Files\data\spoonacular_recipe_list_25.csv')
with open("rl25_list.txt", 'w') as output:
    for row in rl25_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 26 (Cilantro):
data_rl26=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_26.csv')
df_rl26=pd.DataFrame(data_rl26)
df_rl26.columns = df_rl26.columns.str.replace('recipes/', '')
df_rl26.columns = df_rl26.columns.str.replace('/', '_')
rl26_list=[]
for columnName in df_rl26.columns:
    if df_rl26.dtypes[columnName] == 'bool':
        rl26_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl26.dtypes[columnName] == 'object':
        rl26_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl26.dtypes[columnName] == 'int64':
        rl26_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl26.dtypes[columnName] == 'float64':
        rl26_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl26.to_csv('D:\DSE Files\data\spoonacular_recipe_list_26.csv')
with open("rl26_list.txt", 'w') as output:
    for row in rl26_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 27 (Clove):
data_rl27=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_27.csv')
df_rl27=pd.DataFrame(data_rl27)
df_rl27.columns = df_rl27.columns.str.replace('recipes/', '')
df_rl27.columns = df_rl27.columns.str.replace('/', '_')
rl27_list=[]
for columnName in df_rl27.columns:
    if df_rl27.dtypes[columnName] == 'bool':
        rl27_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl27.dtypes[columnName] == 'object':
        rl27_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl27.dtypes[columnName] == 'int64':
        rl27_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl27.dtypes[columnName] == 'float64':
        rl27_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl27.to_csv('D:\DSE Files\data\spoonacular_recipe_list_27.csv')
with open("rl27_list.txt", 'w') as output:
    for row in rl27_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 28 (Cocoa Powder):
data_rl28=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_28.csv')
df_rl28=pd.DataFrame(data_rl28)
df_rl28.columns = df_rl28.columns.str.replace('recipes/', '')
df_rl28.columns = df_rl28.columns.str.replace('/', '_')
rl28_list=[]
for columnName in df_rl28.columns:
    if df_rl28.dtypes[columnName] == 'bool':
        rl28_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl28.dtypes[columnName] == 'object':
        rl28_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl28.dtypes[columnName] == 'int64':
        rl28_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl28.dtypes[columnName] == 'float64':
        rl28_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl28.to_csv('D:\DSE Files\data\spoonacular_recipe_list_28.csv')
with open("rl28_list.txt", 'w') as output:
    for row in rl28_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 29 (Coconut):
data_rl29=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_29.csv')
df_rl29=pd.DataFrame(data_rl29)
df_rl29.columns = df_rl29.columns.str.replace('recipes/', '')
df_rl29.columns = df_rl29.columns.str.replace('/', '_')
rl29_list=[]
for columnName in df_rl29.columns:
    if df_rl29.dtypes[columnName] == 'bool':
        rl29_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl29.dtypes[columnName] == 'object':
        rl29_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl29.dtypes[columnName] == 'int64':
        rl29_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl29.dtypes[columnName] == 'float64':
        rl29_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl29.to_csv('D:\DSE Files\data\spoonacular_recipe_list_29.csv')
with open("rl29_list.txt", 'w') as output:
    for row in rl29_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 30 (Coconut Milk):
data_rl30=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_30.csv')
df_rl30=pd.DataFrame(data_rl30)
df_rl30.columns = df_rl30.columns.str.replace('recipes/', '')
df_rl30.columns = df_rl30.columns.str.replace('/', '_')
rl30_list=[]
for columnName in df_rl30.columns:
    if df_rl30.dtypes[columnName] == 'bool':
        rl30_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl30.dtypes[columnName] == 'object':
        rl30_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl30.dtypes[columnName] == 'int64':
        rl30_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl30.dtypes[columnName] == 'float64':
        rl30_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl30.to_csv('D:\DSE Files\data\spoonacular_recipe_list_30.csv')
with open("rl30_list.txt", 'w') as output:
    for row in rl30_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 31 (Corn Syrup):
data_rl31=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_31.csv')
df_rl31=pd.DataFrame(data_rl31)
df_rl31.columns = df_rl31.columns.str.replace('recipes/', '')
df_rl31.columns = df_rl31.columns.str.replace('/', '_')
rl31_list=[]
for columnName in df_rl31.columns:
    if df_rl31.dtypes[columnName] == 'bool':
        rl31_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl31.dtypes[columnName] == 'object':
        rl31_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl31.dtypes[columnName] == 'int64':
        rl31_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl31.dtypes[columnName] == 'float64':
        rl31_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl31.to_csv('D:\DSE Files\data\spoonacular_recipe_list_31.csv')
with open("rl31_list.txt", 'w') as output:
    for row in rl31_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 32 (Corned Beef):
data_rl32=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_32.csv')
df_rl32=pd.DataFrame(data_rl32)
df_rl32.columns = df_rl32.columns.str.replace('recipes/', '')
df_rl32.columns = df_rl32.columns.str.replace('/', '_')
rl32_list=[]
for columnName in df_rl32.columns:
    if df_rl32.dtypes[columnName] == 'bool':
        rl32_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl32.dtypes[columnName] == 'object':
        rl32_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl32.dtypes[columnName] == 'int64':
        rl32_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl32.dtypes[columnName] == 'float64':
        rl32_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl32.to_csv('D:\DSE Files\data\spoonacular_recipe_list_32.csv')
with open("rl32_list.txt", 'w') as output:
    for row in rl32_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 33 (Cornstarch):
data_rl33=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_33.csv')
df_rl33=pd.DataFrame(data_rl33)
df_rl33.columns = df_rl33.columns.str.replace('recipes/', '')
df_rl33.columns = df_rl33.columns.str.replace('/', '_')
rl33_list=[]
for columnName in df_rl33.columns:
    if df_rl33.dtypes[columnName] == 'bool':
        rl33_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl33.dtypes[columnName] == 'object':
        rl33_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl33.dtypes[columnName] == 'int64':
        rl33_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl33.dtypes[columnName] == 'float64':
        rl33_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl33.to_csv('D:\DSE Files\data\spoonacular_recipe_list_33.csv')
with open("rl33_list.txt", 'w') as output:
    for row in rl33_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 34 (Cow Milk):
data_rl34=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_34.csv')
df_rl34=pd.DataFrame(data_rl34)
df_rl34.columns = df_rl34.columns.str.replace('recipes/', '')
df_rl34.columns = df_rl34.columns.str.replace('/', '_')
rl34_list=[]
for columnName in df_rl34.columns:
    if df_rl34.dtypes[columnName] == 'bool':
        rl34_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl34.dtypes[columnName] == 'object':
        rl34_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl34.dtypes[columnName] == 'int64':
        rl34_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl34.dtypes[columnName] == 'float64':
        rl34_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl34.to_csv('D:\DSE Files\data\spoonacular_recipe_list_34.csv')
with open("rl34_list.txt", 'w') as output:
    for row in rl34_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 35 (Dried Cranberry):
data_rl35=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_35.csv')
df_rl35=pd.DataFrame(data_rl35)
df_rl35.columns = df_rl35.columns.str.replace('recipes/', '')
df_rl35.columns = df_rl35.columns.str.replace('/', '_')
rl35_list=[]
for columnName in df_rl35.columns:
    if df_rl35.dtypes[columnName] == 'bool':
        rl35_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl35.dtypes[columnName] == 'object':
        rl35_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl35.dtypes[columnName] == 'int64':
        rl35_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl35.dtypes[columnName] == 'float64':
        rl35_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl35.to_csv('D:\DSE Files\data\spoonacular_recipe_list_35.csv')
with open("rl35_list.txt", 'w') as output:
    for row in rl35_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 36 (Egg):
data_rl36=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_36.csv')
df_rl36=pd.DataFrame(data_rl36)
df_rl36.columns = df_rl36.columns.str.replace('recipes/', '')
df_rl36.columns = df_rl36.columns.str.replace('/', '_')
rl36_list=[]
for columnName in df_rl36.columns:
    if df_rl36.dtypes[columnName] == 'bool':
        rl36_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl36.dtypes[columnName] == 'object':
        rl36_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl36.dtypes[columnName] == 'int64':
        rl36_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl36.dtypes[columnName] == 'float64':
        rl36_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl36.to_csv('D:\DSE Files\data\spoonacular_recipe_list_36.csv')
with open("rl36_list.txt", 'w') as output:
    for row in rl36_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 37 (Garlic):
data_rl37=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_37.csv')
df_rl37=pd.DataFrame(data_rl37)
df_rl37.columns = df_rl37.columns.str.replace('recipes/', '')
df_rl37.columns = df_rl37.columns.str.replace('/', '_')
rl37_list=[]
for columnName in df_rl37.columns:
    if df_rl37.dtypes[columnName] == 'bool':
        rl37_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl37.dtypes[columnName] == 'object':
        rl37_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl37.dtypes[columnName] == 'int64':
        rl37_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl37.dtypes[columnName] == 'float64':
        rl37_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl37.to_csv('D:\DSE Files\data\spoonacular_recipe_list_37.csv')
with open("rl37_list.txt", 'w') as output:
    for row in rl37_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 38 (Gluten Free Flour):
data_rl38=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_38.csv')
df_rl38=pd.DataFrame(data_rl38)
df_rl38.columns = df_rl38.columns.str.replace('recipes/', '')
df_rl38.columns = df_rl38.columns.str.replace('/', '_')
rl38_list=[]
for columnName in df_rl38.columns:
    if df_rl38.dtypes[columnName] == 'bool':
        rl38_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl38.dtypes[columnName] == 'object':
        rl38_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl38.dtypes[columnName] == 'int64':
        rl38_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl38.dtypes[columnName] == 'float64':
        rl38_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl38.to_csv('D:\DSE Files\data\spoonacular_recipe_list_38.csv')
with open("rl38_list.txt", 'w') as output:
    for row in rl38_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 39 (Green Onion):
data_rl39=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_39.csv')
df_rl39=pd.DataFrame(data_rl39)
df_rl39.columns = df_rl39.columns.str.replace('recipes/', '')
df_rl39.columns = df_rl39.columns.str.replace('/', '_')
rl39_list=[]
for columnName in df_rl39.columns:
    if df_rl39.dtypes[columnName] == 'bool':
        rl39_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl39.dtypes[columnName] == 'object':
        rl39_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl39.dtypes[columnName] == 'int64':
        rl39_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl39.dtypes[columnName] == 'float64':
        rl39_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl39.to_csv('D:\DSE Files\data\spoonacular_recipe_list_39.csv')
with open("rl39_list.txt", 'w') as output:
    for row in rl39_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 40 (Green Pepper):
data_rl40=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_40.csv')
df_rl40=pd.DataFrame(data_rl40)
df_rl40.columns = df_rl40.columns.str.replace('recipes/', '')
df_rl40.columns = df_rl40.columns.str.replace('/', '_')
rl40_list=[]
for columnName in df_rl40.columns:
    if df_rl40.dtypes[columnName] == 'bool':
        rl40_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl40.dtypes[columnName] == 'object':
        rl40_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl40.dtypes[columnName] == 'int64':
        rl40_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl40.dtypes[columnName] == 'float64':
        rl40_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl40.to_csv('D:\DSE Files\data\spoonacular_recipe_list_40.csv')
with open("rl40_list.txt", 'w') as output:
    for row in rl40_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 41 (Honey):
data_rl41=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_41.csv')
df_rl41=pd.DataFrame(data_rl41)
df_rl41.columns = df_rl41.columns.str.replace('recipes/', '')
df_rl41.columns = df_rl41.columns.str.replace('/', '_')
rl41_list=[]
for columnName in df_rl41.columns:
    if df_rl41.dtypes[columnName] == 'bool':
        rl41_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl41.dtypes[columnName] == 'object':
        rl41_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl41.dtypes[columnName] == 'int64':
        rl41_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl41.dtypes[columnName] == 'float64':
        rl41_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl41.to_csv('D:\DSE Files\data\spoonacular_recipe_list_41.csv')
with open("rl41_list.txt", 'w') as output:
    for row in rl41_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 42 (Lamb):
data_rl42=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_42.csv')
df_rl42=pd.DataFrame(data_rl42)
df_rl42.columns = df_rl42.columns.str.replace('recipes/', '')
df_rl42.columns = df_rl42.columns.str.replace('/', '_')
rl42_list=[]
for columnName in df_rl42.columns:
    if df_rl42.dtypes[columnName] == 'bool':
        rl42_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl42.dtypes[columnName] == 'object':
        rl42_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl42.dtypes[columnName] == 'int64':
        rl42_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl42.dtypes[columnName] == 'float64':
        rl42_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl42.to_csv('D:\DSE Files\data\spoonacular_recipe_list_42.csv')
with open("rl42_list.txt", 'w') as output:
    for row in rl42_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 43 (Lemon Juice):
data_rl43=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_43.csv')
df_rl43=pd.DataFrame(data_rl43)
df_rl43.columns = df_rl43.columns.str.replace('recipes/', '')
df_rl43.columns = df_rl43.columns.str.replace('/', '_')
rl43_list=[]
for columnName in df_rl43.columns:
    if df_rl43.dtypes[columnName] == 'bool':
        rl43_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl43.dtypes[columnName] == 'object':
        rl43_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl43.dtypes[columnName] == 'int64':
        rl43_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl43.dtypes[columnName] == 'float64':
        rl43_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl43.to_csv('D:\DSE Files\data\spoonacular_recipe_list_43.csv')
with open("rl43_list.txt", 'w') as output:
    for row in rl43_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 44 (Mayonnaise):
data_rl44=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_44.csv')
df_rl44=pd.DataFrame(data_rl44)
df_rl44.columns = df_rl44.columns.str.replace('recipes/', '')
df_rl44.columns = df_rl44.columns.str.replace('/', '_')
rl44_list=[]
for columnName in df_rl44.columns:
    if df_rl44.dtypes[columnName] == 'bool':
        rl44_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl44.dtypes[columnName] == 'object':
        rl44_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl44.dtypes[columnName] == 'int64':
        rl44_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl44.dtypes[columnName] == 'float64':
        rl44_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl44.to_csv('D:\DSE Files\data\spoonacular_recipe_list_44.csv')
with open("rl44_list.txt", 'w') as output:
    for row in rl44_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 45 (Oat):
data_rl45=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_45.csv')
df_rl45=pd.DataFrame(data_rl45)
df_rl45.columns = df_rl45.columns.str.replace('recipes/', '')
df_rl45.columns = df_rl45.columns.str.replace('/', '_')
rl45_list=[]
for columnName in df_rl45.columns:
    if df_rl45.dtypes[columnName] == 'bool':
        rl45_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl45.dtypes[columnName] == 'object':
        rl45_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl45.dtypes[columnName] == 'int64':
        rl45_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl45.dtypes[columnName] == 'float64':
        rl45_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl45.to_csv('D:\DSE Files\data\spoonacular_recipe_list_45.csv')
with open("rl45_list.txt", 'w') as output:
    for row in rl45_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 46 (Olive Oil):
data_rl46=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_46.csv')
df_rl46=pd.DataFrame(data_rl46)
df_rl46.columns = df_rl46.columns.str.replace('recipes/', '')
df_rl46.columns = df_rl46.columns.str.replace('/', '_')
rl46_list=[]
for columnName in df_rl46.columns:
    if df_rl46.dtypes[columnName] == 'bool':
        rl46_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl46.dtypes[columnName] == 'object':
        rl46_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl46.dtypes[columnName] == 'int64':
        rl46_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl46.dtypes[columnName] == 'float64':
        rl46_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl46.to_csv('D:\DSE Files\data\spoonacular_recipe_list_46.csv')
with open("rl46_list.txt", 'w') as output:
    for row in rl46_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 47 (Onion):
data_rl47=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_47.csv')
df_rl47=pd.DataFrame(data_rl47)
df_rl47.columns = df_rl47.columns.str.replace('recipes/', '')
df_rl47.columns = df_rl47.columns.str.replace('/', '_')
rl47_list=[]
for columnName in df_rl47.columns:
    if df_rl47.dtypes[columnName] == 'bool':
        rl47_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl47.dtypes[columnName] == 'object':
        rl47_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl47.dtypes[columnName] == 'int64':
        rl47_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl47.dtypes[columnName] == 'float64':
        rl47_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl47.to_csv('D:\DSE Files\data\spoonacular_recipe_list_47.csv')
with open("rl47_list.txt", 'w') as output:
    for row in rl47_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 48 (Oregano):
data_rl48=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_48.csv')
df_rl48=pd.DataFrame(data_rl48)
df_rl48.columns = df_rl48.columns.str.replace('recipes/', '')
df_rl48.columns = df_rl48.columns.str.replace('/', '_')
rl48_list=[]
for columnName in df_rl48.columns:
    if df_rl48.dtypes[columnName] == 'bool':
        rl48_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl48.dtypes[columnName] == 'object':
        rl48_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl48.dtypes[columnName] == 'int64':
        rl48_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl48.dtypes[columnName] == 'float64':
        rl48_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl48.to_csv('D:\DSE Files\data\spoonacular_recipe_list_48.csv')
with open("rl48_list.txt", 'w') as output:
    for row in rl48_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 49 (Paprika):
data_rl49=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_49.csv')
df_rl49=pd.DataFrame(data_rl49)
df_rl49.columns = df_rl49.columns.str.replace('recipes/', '')
df_rl49.columns = df_rl49.columns.str.replace('/', '_')
rl49_list=[]
for columnName in df_rl49.columns:
    if df_rl49.dtypes[columnName] == 'bool':
        rl49_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl49.dtypes[columnName] == 'object':
        rl49_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl49.dtypes[columnName] == 'int64':
        rl49_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl49.dtypes[columnName] == 'float64':
        rl49_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl49.to_csv('D:\DSE Files\data\spoonacular_recipe_list_49.csv')
with open("rl49_list.txt", 'w') as output:
    for row in rl49_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 50 (Parsley):
data_rl50=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_50.csv')
df_rl50=pd.DataFrame(data_rl50)
df_rl50.columns = df_rl50.columns.str.replace('recipes/', '')
df_rl50.columns = df_rl50.columns.str.replace('/', '_')
rl50_list=[]
for columnName in df_rl50.columns:
    if df_rl50.dtypes[columnName] == 'bool':
        rl50_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl50.dtypes[columnName] == 'object':
        rl50_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl50.dtypes[columnName] == 'int64':
        rl50_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl50.dtypes[columnName] == 'float64':
        rl50_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl50.to_csv('D:\DSE Files\data\spoonacular_recipe_list_50.csv')
with open("rl50_list.txt", 'w') as output:
    for row in rl50_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 51 (Peanut):
data_rl51=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_51.csv')
df_rl51=pd.DataFrame(data_rl51)
df_rl51.columns = df_rl51.columns.str.replace('recipes/', '')
df_rl51.columns = df_rl51.columns.str.replace('/', '_')
rl51_list=[]
for columnName in df_rl51.columns:
    if df_rl51.dtypes[columnName] == 'bool':
        rl51_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl51.dtypes[columnName] == 'object':
        rl51_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl51.dtypes[columnName] == 'int64':
        rl51_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl51.dtypes[columnName] == 'float64':
        rl51_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl51.to_csv('D:\DSE Files\data\spoonacular_recipe_list_51.csv')
with open("rl51_list.txt", 'w') as output:
    for row in rl51_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 52 (Pecan):
data_rl52=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_52.csv')
df_rl52=pd.DataFrame(data_rl52)
df_rl52.columns = df_rl52.columns.str.replace('recipes/', '')
df_rl52.columns = df_rl52.columns.str.replace('/', '_')
rl52_list=[]
for columnName in df_rl52.columns:
    if df_rl52.dtypes[columnName] == 'bool':
        rl52_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl52.dtypes[columnName] == 'object':
        rl52_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl52.dtypes[columnName] == 'int64':
        rl52_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl52.dtypes[columnName] == 'float64':
        rl52_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl52.to_csv('D:\DSE Files\data\spoonacular_recipe_list_52.csv')
with open("rl52_list.txt", 'w') as output:
    for row in rl52_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 53 (Potato):
data_rl53=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_53.csv')
df_rl53=pd.DataFrame(data_rl53)
df_rl53.columns = df_rl53.columns.str.replace('recipes/', '')
df_rl53.columns = df_rl53.columns.str.replace('/', '_')
rl53_list=[]
for columnName in df_rl53.columns:
    if df_rl53.dtypes[columnName] == 'bool':
        rl53_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl53.dtypes[columnName] == 'object':
        rl53_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl53.dtypes[columnName] == 'int64':
        rl53_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl53.dtypes[columnName] == 'float64':
        rl53_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl53.to_csv('D:\DSE Files\data\spoonacular_recipe_list_53.csv')
with open("rl53_list.txt", 'w') as output:
    for row in rl53_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 54 (Pumpkin Seed):
data_rl54=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_54.csv')
df_rl54=pd.DataFrame(data_rl54)
df_rl54.columns = df_rl54.columns.str.replace('recipes/', '')
df_rl54.columns = df_rl54.columns.str.replace('/', '_')
rl54_list=[]
for columnName in df_rl54.columns:
    if df_rl54.dtypes[columnName] == 'bool':
        rl54_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl54.dtypes[columnName] == 'object':
        rl54_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl54.dtypes[columnName] == 'int64':
        rl54_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl54.dtypes[columnName] == 'float64':
        rl54_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl54.to_csv('D:\DSE Files\data\spoonacular_recipe_list_54.csv')
with open("rl54_list.txt", 'w') as output:
    for row in rl54_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 55 (Crab):
data_rl55=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_55.csv')
df_rl55=pd.DataFrame(data_rl55)
df_rl55.columns = df_rl55.columns.str.replace('recipes/', '')
df_rl55.columns = df_rl55.columns.str.replace('/', '_')
rl55_list=[]
for columnName in df_rl55.columns:
    if df_rl55.dtypes[columnName] == 'bool':
        rl55_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl55.dtypes[columnName] == 'object':
        rl55_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl55.dtypes[columnName] == 'int64':
        rl55_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl55.dtypes[columnName] == 'float64':
        rl55_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl55.to_csv('D:\DSE Files\data\spoonacular_recipe_list_55.csv')
with open("rl55_list.txt", 'w') as output:
    for row in rl55_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 56 (Salt):
data_rl56=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_56.csv')
df_rl56=pd.DataFrame(data_rl56)
df_rl56.columns = df_rl56.columns.str.replace('recipes/', '')
df_rl56.columns = df_rl56.columns.str.replace('/', '_')
rl56_list=[]
for columnName in df_rl56.columns:
    if df_rl56.dtypes[columnName] == 'bool':
        rl56_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl56.dtypes[columnName] == 'object':
        rl56_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl56.dtypes[columnName] == 'int64':
        rl56_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl56.dtypes[columnName] == 'float64':
        rl56_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl56.to_csv('D:\DSE Files\data\spoonacular_recipe_list_56.csv')
with open("rl56_list.txt", 'w') as output:
    for row in rl56_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 57 (Sesame Oil):
data_rl57=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_57.csv')
df_rl57=pd.DataFrame(data_rl57)
df_rl57.columns = df_rl57.columns.str.replace('recipes/', '')
df_rl57.columns = df_rl57.columns.str.replace('/', '_')
rl57_list=[]
for columnName in df_rl57.columns:
    if df_rl57.dtypes[columnName] == 'bool':
        rl57_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl57.dtypes[columnName] == 'object':
        rl57_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl57.dtypes[columnName] == 'int64':
        rl57_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl57.dtypes[columnName] == 'float64':
        rl57_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl57.to_csv('D:\DSE Files\data\spoonacular_recipe_list_57.csv')
with open("rl57_list.txt", 'w') as output:
    for row in rl57_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 58 (Soy Sauce):
data_rl58=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_58.csv')
df_rl58=pd.DataFrame(data_rl58)
df_rl58.columns = df_rl58.columns.str.replace('recipes/', '')
df_rl58.columns = df_rl58.columns.str.replace('/', '_')
rl58_list=[]
for columnName in df_rl58.columns:
    if df_rl58.dtypes[columnName] == 'bool':
        rl58_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl58.dtypes[columnName] == 'object':
        rl58_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl58.dtypes[columnName] == 'int64':
        rl58_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl58.dtypes[columnName] == 'float64':
        rl58_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl58.to_csv('D:\DSE Files\data\spoonacular_recipe_list_58.csv')
with open("rl58_list.txt", 'w') as output:
    for row in rl58_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 59 (Tapioca Flour):
data_rl59=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_59.csv')
df_rl59=pd.DataFrame(data_rl59)
df_rl59.columns = df_rl59.columns.str.replace('recipes/', '')
df_rl59.columns = df_rl59.columns.str.replace('/', '_')
rl59_list=[]
for columnName in df_rl59.columns:
    if df_rl59.dtypes[columnName] == 'bool':
        rl59_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl59.dtypes[columnName] == 'object':
        rl59_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl59.dtypes[columnName] == 'int64':
        rl59_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl59.dtypes[columnName] == 'float64':
        rl59_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl59.to_csv('D:\DSE Files\data\spoonacular_recipe_list_59.csv')
with open("rl59_list.txt", 'w') as output:
    for row in rl59_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 60 (Tarragon):
data_rl60=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_60.csv')
df_rl60=pd.DataFrame(data_rl60)
df_rl60.columns = df_rl60.columns.str.replace('recipes/', '')
df_rl60.columns = df_rl60.columns.str.replace('/', '_')
rl60_list=[]
for columnName in df_rl60.columns:
    if df_rl60.dtypes[columnName] == 'bool':
        rl60_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl60.dtypes[columnName] == 'object':
        rl60_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl60.dtypes[columnName] == 'int64':
        rl60_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl60.dtypes[columnName] == 'float64':
        rl60_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl60.to_csv('D:\DSE Files\data\spoonacular_recipe_list_60.csv')
with open("rl60_list.txt", 'w') as output:
    for row in rl60_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 61 (Seaweed):
data_rl61=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_61.csv')
df_rl61=pd.DataFrame(data_rl61)
df_rl61.columns = df_rl61.columns.str.replace('recipes/', '')
df_rl61.columns = df_rl61.columns.str.replace('/', '_')
rl61_list=[]
for columnName in df_rl61.columns:
    if df_rl61.dtypes[columnName] == 'bool':
        rl61_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl61.dtypes[columnName] == 'object':
        rl61_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl61.dtypes[columnName] == 'int64':
        rl61_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl61.dtypes[columnName] == 'float64':
        rl61_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl61.to_csv('D:\DSE Files\data\spoonacular_recipe_list_61.csv')
with open("rl61_list.txt", 'w') as output:
    for row in rl61_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 62 (Tomato):
data_rl62=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_62.csv')
df_rl62=pd.DataFrame(data_rl62)
df_rl62.columns = df_rl62.columns.str.replace('recipes/', '')
df_rl62.columns = df_rl62.columns.str.replace('/', '_')
rl62_list=[]
for columnName in df_rl62.columns:
    if df_rl62.dtypes[columnName] == 'bool':
        rl62_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl62.dtypes[columnName] == 'object':
        rl62_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl62.dtypes[columnName] == 'int64':
        rl62_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl62.dtypes[columnName] == 'float64':
        rl62_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl62.to_csv('D:\DSE Files\data\spoonacular_recipe_list_62.csv')
with open("rl62_list.txt", 'w') as output:
    for row in rl62_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 63 (Vanilla Extract):
data_rl63=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_63.csv')
df_rl63=pd.DataFrame(data_rl63)
df_rl63.columns = df_rl63.columns.str.replace('recipes/', '')
df_rl63.columns = df_rl63.columns.str.replace('/', '_')
rl63_list=[]
for columnName in df_rl63.columns:
    if df_rl63.dtypes[columnName] == 'bool':
        rl63_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl63.dtypes[columnName] == 'object':
        rl63_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl63.dtypes[columnName] == 'int64':
        rl63_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl63.dtypes[columnName] == 'float64':
        rl63_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl63.to_csv('D:\DSE Files\data\spoonacular_recipe_list_63.csv')
with open("rl63_list.txt", 'w') as output:
    for row in rl63_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 64 (Vegetable Oil):
data_rl64=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_64.csv')
df_rl64=pd.DataFrame(data_rl64)
df_rl64.columns = df_rl64.columns.str.replace('recipes/', '')
df_rl64.columns = df_rl64.columns.str.replace('/', '_')
rl64_list=[]
for columnName in df_rl64.columns:
    if df_rl64.dtypes[columnName] == 'bool':
        rl64_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl64.dtypes[columnName] == 'object':
        rl64_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl64.dtypes[columnName] == 'int64':
        rl64_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl64.dtypes[columnName] == 'float64':
        rl64_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl64.to_csv('D:\DSE Files\data\spoonacular_recipe_list_64.csv')
with open("rl64_list.txt", 'w') as output:
    for row in rl64_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 65 (Walnut):
data_rl65=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_65.csv')
df_rl65=pd.DataFrame(data_rl65)
df_rl65.columns = df_rl65.columns.str.replace('recipes/', '')
df_rl65.columns = df_rl65.columns.str.replace('/', '_')
rl65_list=[]
for columnName in df_rl65.columns:
    if df_rl65.dtypes[columnName] == 'bool':
        rl65_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl65.dtypes[columnName] == 'object':
        rl65_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl65.dtypes[columnName] == 'int64':
        rl65_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl65.dtypes[columnName] == 'float64':
        rl65_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl65.to_csv('D:\DSE Files\data\spoonacular_recipe_list_65.csv')
with open("rl65_list.txt", 'w') as output:
    for row in rl65_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 66 (Water):
data_rl66=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_66.csv')
df_rl66=pd.DataFrame(data_rl66)
df_rl66.columns = df_rl66.columns.str.replace('recipes/', '')
df_rl66.columns = df_rl66.columns.str.replace('/', '_')
rl66_list=[]
for columnName in df_rl66.columns:
    if df_rl66.dtypes[columnName] == 'bool':
        rl66_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl66.dtypes[columnName] == 'object':
        rl66_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl66.dtypes[columnName] == 'int64':
        rl66_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl66.dtypes[columnName] == 'float64':
        rl66_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl66.to_csv('D:\DSE Files\data\spoonacular_recipe_list_66.csv')
with open("rl66_list.txt", 'w') as output:
    for row in rl66_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 67 (Bread):
data_rl67=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_67.csv')
df_rl67=pd.DataFrame(data_rl67)
df_rl67.columns = df_rl67.columns.str.replace('recipes/', '')
df_rl67.columns = df_rl67.columns.str.replace('/', '_')
rl67_list=[]
for columnName in df_rl67.columns:
    if df_rl67.dtypes[columnName] == 'bool':
        rl67_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl67.dtypes[columnName] == 'object':
        rl67_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl67.dtypes[columnName] == 'int64':
        rl67_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl67.dtypes[columnName] == 'float64':
        rl67_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl67.to_csv('D:\DSE Files\data\spoonacular_recipe_list_67.csv')
with open("rl67_list.txt", 'w') as output:
    for row in rl67_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 68 (Shrimp):
data_rl68=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_68.csv')
df_rl68=pd.DataFrame(data_rl68)
df_rl68.columns = df_rl68.columns.str.replace('recipes/', '')
df_rl68.columns = df_rl68.columns.str.replace('/', '_')
rl68_list=[]
for columnName in df_rl68.columns:
    if df_rl68.dtypes[columnName] == 'bool':
        rl68_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl68.dtypes[columnName] == 'object':
        rl68_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl68.dtypes[columnName] == 'int64':
        rl68_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl68.dtypes[columnName] == 'float64':
        rl68_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl68.to_csv('D:\DSE Files\data\spoonacular_recipe_list_68.csv')
with open("rl68_list.txt", 'w') as output:
    for row in rl68_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 69 (White Vinegar):
data_rl69=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_69.csv')
df_rl69=pd.DataFrame(data_rl69)
df_rl69.columns = df_rl69.columns.str.replace('recipes/', '')
df_rl69.columns = df_rl69.columns.str.replace('/', '_')
rl69_list=[]
for columnName in df_rl69.columns:
    if df_rl69.dtypes[columnName] == 'bool':
        rl69_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl69.dtypes[columnName] == 'object':
        rl69_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl69.dtypes[columnName] == 'int64':
        rl69_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl69.dtypes[columnName] == 'float64':
        rl69_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl69.to_csv('D:\DSE Files\data\spoonacular_recipe_list_69.csv')
with open("rl69_list.txt", 'w') as output:
    for row in rl69_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 70 (Mustard):
data_rl70=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_70.csv')
df_rl70=pd.DataFrame(data_rl70)
df_rl70.columns = df_rl70.columns.str.replace('recipes/', '')
df_rl70.columns = df_rl70.columns.str.replace('/', '_')
rl70_list=[]
for columnName in df_rl70.columns:
    if df_rl70.dtypes[columnName] == 'bool':
        rl70_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl70.dtypes[columnName] == 'object':
        rl70_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl70.dtypes[columnName] == 'int64':
        rl70_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl70.dtypes[columnName] == 'float64':
        rl70_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl70.to_csv('D:\DSE Files\data\spoonacular_recipe_list_70.csv')
with open("rl70_list.txt", 'w') as output:
    for row in rl70_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 71 (Whole Wheat Flour):
data_rl71=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_71.csv')
df_rl71=pd.DataFrame(data_rl71)
df_rl71.columns = df_rl71.columns.str.replace('recipes/', '')
df_rl71.columns = df_rl71.columns.str.replace('/', '_')
rl71_list=[]
for columnName in df_rl71.columns:
    if df_rl71.dtypes[columnName] == 'bool':
        rl71_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl71.dtypes[columnName] == 'object':
        rl71_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl71.dtypes[columnName] == 'int64':
        rl71_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl71.dtypes[columnName] == 'float64':
        rl71_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl71.to_csv('D:\DSE Files\data\spoonacular_recipe_list_71.csv')
with open("rl71_list.txt", 'w') as output:
    for row in rl71_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 72 (Chocolate):
data_rl72=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_72.csv')
df_rl72=pd.DataFrame(data_rl72)
df_rl72.columns = df_rl72.columns.str.replace('recipes/', '')
df_rl72.columns = df_rl72.columns.str.replace('/', '_')
rl72_list=[]
for columnName in df_rl72.columns:
    if df_rl72.dtypes[columnName] == 'bool':
        rl72_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl72.dtypes[columnName] == 'object':
        rl72_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl72.dtypes[columnName] == 'int64':
        rl72_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl72.dtypes[columnName] == 'float64':
        rl72_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl72.to_csv('D:\DSE Files\data\spoonacular_recipe_list_72.csv')
with open("rl72_list.txt", 'w') as output:
    for row in rl72_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 73 (Duck):
data_rl73=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_73.csv')
df_rl73=pd.DataFrame(data_rl73)
df_rl73.columns = df_rl73.columns.str.replace('recipes/', '')
df_rl73.columns = df_rl73.columns.str.replace('/', '_')
rl73_list=[]
for columnName in df_rl73.columns:
    if df_rl73.dtypes[columnName] == 'bool':
        rl73_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl73.dtypes[columnName] == 'object':
        rl73_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl73.dtypes[columnName] == 'int64':
        rl73_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl73.dtypes[columnName] == 'float64':
        rl73_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl73.to_csv('D:\DSE Files\data\spoonacular_recipe_list_73.csv')
with open("rl73_list.txt", 'w') as output:
    for row in rl73_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 74 (Strawberry):
data_rl74=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_74.csv')
df_rl74=pd.DataFrame(data_rl74)
df_rl74.columns = df_rl74.columns.str.replace('recipes/', '')
df_rl74.columns = df_rl74.columns.str.replace('/', '_')
rl74_list=[]
for columnName in df_rl74.columns:
    if df_rl74.dtypes[columnName] == 'bool':
        rl74_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl74.dtypes[columnName] == 'object':
        rl74_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl74.dtypes[columnName] == 'int64':
        rl74_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl74.dtypes[columnName] == 'float64':
        rl74_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl74.to_csv('D:\DSE Files\data\spoonacular_recipe_list_74.csv')
with open("rl74_list.txt", 'w') as output:
    for row in rl74_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 75 (Mushroom):
data_rl75=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_75.csv')
df_rl75=pd.DataFrame(data_rl75)
df_rl75.columns = df_rl75.columns.str.replace('recipes/', '')
df_rl75.columns = df_rl75.columns.str.replace('/', '_')
rl75_list=[]
for columnName in df_rl75.columns:
    if df_rl75.dtypes[columnName] == 'bool':
        rl75_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl75.dtypes[columnName] == 'object':
        rl75_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl75.dtypes[columnName] == 'int64':
        rl75_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl75.dtypes[columnName] == 'float64':
        rl75_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl75.to_csv('D:\DSE Files\data\spoonacular_recipe_list_75.csv')
with open("rl75_list.txt", 'w') as output:
    for row in rl75_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 76 (Anchovy):
data_rl76=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_76.csv')
df_rl76=pd.DataFrame(data_rl76)
df_rl76.columns = df_rl76.columns.str.replace('recipes/', '')
df_rl76.columns = df_rl76.columns.str.replace('/', '_')
rl76_list=[]
for columnName in df_rl76.columns:
    if df_rl76.dtypes[columnName] == 'bool':
        rl76_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl76.dtypes[columnName] == 'object':
        rl76_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl76.dtypes[columnName] == 'int64':
        rl76_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl76.dtypes[columnName] == 'float64':
        rl76_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl76.to_csv('D:\DSE Files\data\spoonacular_recipe_list_76.csv')
with open("rl76_list.txt", 'w') as output:
    for row in rl76_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 77 (Crawfish):
data_rl77=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_77.csv')
df_rl77=pd.DataFrame(data_rl77)
df_rl77.columns = df_rl77.columns.str.replace('recipes/', '')
df_rl77.columns = df_rl77.columns.str.replace('/', '_')
rl77_list=[]
for columnName in df_rl77.columns:
    if df_rl77.dtypes[columnName] == 'bool':
        rl77_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl77.dtypes[columnName] == 'object':
        rl77_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl77.dtypes[columnName] == 'int64':
        rl77_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl77.dtypes[columnName] == 'float64':
        rl77_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl77.to_csv('D:\DSE Files\data\spoonacular_recipe_list_77.csv')
with open("rl77_list.txt", 'w') as output:
    for row in rl77_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 78 (Apple):
data_rl78=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_78.csv')
df_rl78=pd.DataFrame(data_rl78)
df_rl78.columns = df_rl78.columns.str.replace('recipes/', '')
df_rl78.columns = df_rl78.columns.str.replace('/', '_')
rl78_list=[]
for columnName in df_rl78.columns:
    if df_rl78.dtypes[columnName] == 'bool':
        rl78_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl78.dtypes[columnName] == 'object':
        rl78_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl78.dtypes[columnName] == 'int64':
        rl78_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl78.dtypes[columnName] == 'float64':
        rl78_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl78.to_csv('D:\DSE Files\data\spoonacular_recipe_list_78.csv')
with open("rl78_list.txt", 'w') as output:
    for row in rl78_list:
        output.write(str(row) + ',\n')

# %%
#Output Neo4j Column Types in Recipe List 79 (Cheese):
data_rl79=pd.read_csv(r'D:\DSE Files\data\spoonacular_recipe_list_79.csv')
df_rl79=pd.DataFrame(data_rl79)
df_rl79.columns = df_rl79.columns.str.replace('recipes/', '')
df_rl79.columns = df_rl79.columns.str.replace('/', '_')
rl79_list=[]
for columnName in df_rl79.columns:
    if df_rl79.dtypes[columnName] == 'bool':
        rl79_list.append("%s: toBoolean(csvLine.%s)" % (columnName, columnName))
    if df_rl79.dtypes[columnName] == 'object':
        rl79_list.append("%s: csvLine.%s" % (columnName, columnName))
    if df_rl79.dtypes[columnName] == 'int64':
        rl79_list.append("%s: toInteger(csvLine.%s)" % (columnName, columnName))
    if df_rl79.dtypes[columnName] == 'float64':
        rl79_list.append("%s: toFloat(csvLine.%s)" % (columnName, columnName))
df_rl79.to_csv('D:\DSE Files\data\spoonacular_recipe_list_79.csv')
with open("rl79_list.txt", 'w') as output:
    for row in rl79_list:
        output.write(str(row) + ',\n')
